# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
scale_mat = df_mat / 24

scale_por = df_por / 18

scale_geo = df_geo / 8
  
scale_ing = df_ing / 8

scale_his = df_his / 8

scale_fis = df_fis / 12

scale_qui = df_qui / 12

# %%
# 2) Seu código aqui

total_acertos = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total_acertos
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
(total_acertos/90) * 100
# Out:
#     Qt_acertos
# 0    38.888889
# 1    53.333333
# 2    55.555556
# 3    35.555556
# 4    33.333333
# ..         ...
# 95   37.777778
# 96   30.000000
# 97   44.444444
# 98   44.444444
# 99   46.666667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
segunda_fase_45 = total_acertos[total_acertos['Qt_acertos'] > 45]
segunda_fase_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
#1 e 2 seu código aqui
desqualifica = total_acertos[(df_mat['Qt_acertos'] == 0) |
                             (df_fis['Qt_acertos'] == 0) |
                             (df_qui['Qt_acertos'] == 0)]

desqualifica.count()
# Out:
# Qt_acertos    23
# dtype: int64

# %%
media_geo_hist = pd.DataFrame(desqualifica)
media_geo_hist['Média'] = (df_geo + df_his)/16
media_geo_hist
# Out:
#     Qt_acertos   Média
# 3           32  0.1875
# 6           29  0.7500
# 10          31  0.2500
# 12          42  0.2500
# 14          31  0.1250
# 20          53  0.7500
# 25          27  0.4375
# 26          40  0.8125
# 27          50  0.5000
# 33          39  0.3750
# 35          48  0.5625
# 49          19  0.1250
# 56          39  0.8125
# 65          24  0.3125
# 66          31  0.3750
# 72          50  0.6250
# 73          37  0.3125
# 74          39  0.3125
# 84          26  0.0625
# 89          63  0.8125
# 92          40  0.1250
# 94          25  0.1875
# 98          40  0.5000

# %%
aprovados = total_acertos[(df_mat['Qt_acertos'] > 0) &
                             (df_fis['Qt_acertos'] > 0) &
                             (df_qui['Qt_acertos'] > 0) &
                             (total_acertos['Qt_acertos'] > 45)]

aprovados.count()
# Out:
# Qt_acertos    26
# dtype: int64

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
#Aqui eu peguei do site, o link de antes estava desatualizado 
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00001-4d75f3af-a3d9-4764-a2d3-03ff9d6b5fce.c000.csv'

# %%
# 1) Sua solução aqui
df = pd.read_csv(arquivo, sep=';')
# Out:
# C:\Users\GuardianKotarou\AppData\Local\Temp\ipykernel_2972\2145173094.py:2: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(arquivo, sep=';')

# %%
df.head()
# Out:
#                                  document_id  \
# 0  3dbfc272-d68f-4a26-a146-abf9c505962b-i0b0
# 1  a42fe3c1-8b43-4a53-8668-b246081dc546-i0b0
# 2  a5efe5e3-f196-45c7-a21c-051a1677e0a5-i0b0
# 3  a43a32b6-7bf9-4f9f-ade5-7ac00b302188-i0b0
# 4  078eecc7-8e56-4ac6-908e-ecc6c74d9770-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  4a70b24216e2eaaf33bead3ae3f1bb859a04c7a5774d89...            36.0
# 1  b3592e4170b205090a2c7cc8d649954069c2cb9eb283d3...            71.0
# 2  a4cd5e20de7ab8088fdcbfd519682632c96575f0ff37a5...            20.0
# 3  39d968f7a92123f0a1ad6ebb83de9eff8a787f0258df8f...            27.0
# 4  1a66e2efb42cea9d4cae20c7225e97253559defd5701de...            54.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1984-10-04                          M                      4.0
# 1              1950-01-24                          F                      3.0
# ...

# %%
df['vacina_codigo'].count()
# Out:
# 351056

# %%
# 2) 
df['paciente_id'].nunique()
# Out:
# 292943

# %%
# 3) 

primeiradose = df['vacina_descricao_dose'].unique()[1]
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeiradose].nunique()
# Out:
# 139837

# %%
# 3) Solução Alternativa
#Não conheço, me falta conhecimento, mas vou buscar

# %%
# 4) 
menor = df[df['paciente_idade'] < 18]
menor['paciente_id'].nunique()
# Out:
# 55199

# %%
# 5)
#Não sei qual estabelicimento então vou colar todos 
print(df['estabelecimento_razaoSocial'].nunique())
print(df['estabelecimento_municipio_codigo'].nunique())
print(df['estabelecimento_municipio_nome'].nunique())
print(df['estabelecimento_uf'].nunique())
# Out:
# 50
# 22
# 22
# 1

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 

Vacinamenor = df[df['paciente_idade']< 18].copy()
Vacinamenor
# Out:
#                                       document_id  \
# 5       a442c51b-631b-4b83-864b-7105c73cc2aa-i0b0
# 19      a5e740fa-e945-4ba3-84cb-4c8d79dd06fe-i0b0
# 26      36986b59-c6e0-4010-99e9-fef3f23cf8a0-i0b0
# 34      3e45f7c5-a574-404d-befc-bee295adb4df-i0b0
# 40      a488e17e-cade-4169-aea9-7ea6b66167b6-i0b0
# ...                                           ...
# 351041  ef07ceac-a6db-4e5b-9e3d-e7950ff20fc7-i0b0
# 351044  efa283bd-c897-40ae-b1f3-bb3086bce014-i0b0
# 351050  f013d2b0-5361-417c-8ae4-be17f23a5928-i0b0
# 351053  f03a0edf-0bd5-4cd5-9aab-dbda4f77a5ae-i0b0
# 351054  f06437af-41cc-42d6-a7af-778d3456ab5a-i0b0
#
#                                               paciente_id  paciente_idade  \
# 5       05537525bdfe1ff0db260bd44c69b1b68d069e1a3c0a66...            15.0
# 19      397201137bbc9a1038c5f0b3fbbc035f402f2beec695fb...            13.0
# 26      ee4c2958137ef37621eaba7a62648856a90f013d11e581...            12.0
# ...

# %%
# 2) 
Vacinamenor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)

contagem = df['vacina_categoria_nome'].value_counts()
contagem
# Out:
# Faixa Etária                                       242745
# Comorbidades                                        23993
# Trabalhadores de Saúde                              14763
# Povos e Comunidades Tradicionais                    10307
# Trabalhadores da Educação                            9893
# Povos Indígenas                                      8023
# Outros                                               4329
# Trabalhadores Industriais                            3850
# População Privada de Liberdade                       2641
# Pessoas de 60 anos ou mais institucionalizadas       2565
# Pessoas com Deficiência                              1928
# Forças de Segurança e Salvamento                     1676
# Gestantes                                            1241
# Trabalhadores de Transporte                           836
# Funcionário do Sistema de Privação de Liberdade       769
# Forças Armadas (membros ativos)                       451
# ...

# %%
# 4)

lista_estabelecimento = ['estabelecimento_valor', 'estabelecimento_razaoSocial', 
                         'estalecimento_noFantasia', 'estabelecimento_municipio_codigo', 
                         'estabelecimento_municipio_nome', 'estabelecimento_uf']
menorlista = Vacinamenor.loc[:, lista_estabelecimento]

menorlista
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 5                     2000326  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 19                    2000016  PREFEITURA MUNICIPAL DE RODRIGUES ALVES
# 26                    2000016  PREFEITURA MUNICIPAL DE RODRIGUES ALVES
# 34                    2000016  PREFEITURA MUNICIPAL DE RODRIGUES ALVES
# 40                    5981891  PREFEITURA MUNICIIPAL DE SENA MADUREIRA
# ...                       ...                                      ...
# 351041                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 351044                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 351050                6159087  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 351053                2000040            PREFEITURA MUNICIPAL DE FEIJO
# 351054                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                  estalecimento_noFantasia  \
# ...

# %%
novalista = menorlista.drop_duplicates()
novalista
# Out:
#         estabelecimento_valor               estabelecimento_razaoSocial  \
# 5                     2000326   PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 19                    2000016   PREFEITURA MUNICIPAL DE RODRIGUES ALVES
# 40                    5981891   PREFEITURA MUNICIIPAL DE SENA MADUREIRA
# 41                    5354072            PREFEITURA MUNICIPAL DE JORDAO
# 46                    6917291        PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                       ...                                       ...
# 122938                9296042  PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# 157924                7168748       PREFEITURA MUNICIPAL DE MANCIO LIMA
# 193230                 115606                       K M OLIVEIRA EIRELI
# 251735                2000296             SECRETARIA DE ESTADO DE SAUDE
# 315641                5336171     SECRETARIA DE ESTADO DE SAUDE DO ACRE
#
#                                  estalecimento_noFantasia  \
# ...
